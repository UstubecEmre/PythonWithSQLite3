# %% [markdown]
# # SQL Nedir?
# **SQL (Structured Query Language)**, veri ile çalışan herkesin öğrenmesi gerektiğini düşündüğüm oldukça önemli bir dildir.
#
# Türkçemize <mark><em>*Yapılandırılmış Sorgu Dili*</em></mark> olarak çevrilmiştir.
#
# SQL sayesinde ilişkisel veritabanlarında **CRUD(Create, Read, Update, Delete)** işlemlerini gerçekleştirebilirz:
# - Veri ekleme (INSERT)
#
# - Veri silme (DELETE)
#
# - Veri güncelleme (UPDATE)
#
# - Veri sorgulama (SELECT)
# gibi işlemler gerçekleştirilir.
#
# Veri tabanlarını kısaca SQL ve NoSQL olarak ikiye ayırabiliriz.
# Burada veri türümüzün yapısına (Yapısal ve yapısal olmayan veri) göre veri tabanı tercihi gerçekleştirmemiz gerekmektedir.
#
# **İlişkisel Veritabanı Örnekleri:**
# - MS SQL
# - MySQL
# - Oracle
# - PostgreSQL
# - MS Access
# ---
#
# # Veri Tabanı Nedir?
# Veri tabanı, kısacası verileri saklamamıza ve düzenli bir şekilde yönetmemize yardımcı olan sistemlerdir diyebiliriz.
#
# 💡Veri tabanlarının geçmişi yazının icadı kadar eskidir de diyebiliriz. Çok komplex olarak düşünmememiz gerekmektedir. Bilgilerimizi tutmamıza, sakmamıza yardımcı olan ne varsa birer veritabanıdır.
#
# Basit bir benzetme: Kullandığımız not defteri de bir veri tabanı gibi düşünülebilir. Orada sizin mantığınıza göre bilgileri tutuyorsunuz, dilediğiniz vakit oraya bilgi ekleyebiliyor, siliyor ve güncelleme yapabiliyorsunuz.
#
# Daha teknik olarak ise, sizlerin de aşina olduğu OBS (Öğrenci Bilgi Sistemleri) düşünülebilir. Burada sizlerin öğrenci bilgileri (kayıt tarihinizden aldığınız derslere, almanız gereken krediden harf notlarınıza kadar olan tüm bilgiler)  tablo şeklinde arka planda saklanmakta ve birbiriyle ilişki içerisinde bulunmaktadır.
#
# ---
#
# ## SQL ve NoSQL
# Veritabanlarını temelde ikiye ayırabiliriz:
#
# ### 🔹 SQL (Relational Databases)
# - Yapısal (structured) veriler için uygundur. Bu verilerin belirli bir kalıbı vardır, excele kaydedebileceğiniz bilgiler olarak düşünebilirsiniz.
# - Tablo yapısına dayanır. Excel örneğinden devam edelim, burada bilgilerimizi satır ve sütunlara kaydediyoruz öyle değil mi? (satırlar = kayıtlarımızı, sütunlar = özelliklerimiz ifade etmektedir).
# - Veri bütünlüğü ve ilişkiler önemlidir. OBS örneğinden yola çıkarsak almanız gereken ders kredisi ile almış olduğunuz ders kredisi ilişkili olmasaydı nasıl mezun olacaktınız?
# - Örn: MS SQL, Oracle, PostgreSQL, MySQL vb.
#
# ### 🔹 NoSQL (Not Only SQL)
# - Yapısal olmayan veya yarı-yapısal veriler için uygundur. Buna örnek olarak sosyal medya içerikleri, videolar, fotoğraflar, e-posta metinleri vb. verilebilir
# - Esnek şema yapısı vardır. Örnek olarak bir fotoğraf içerisinde başka fotoğraflar yer alabilir. Bir diğerinde fotoğraf olma zorunluluğu yoktur.
# - Büyük veri ve yüksek performans gereken sistemlerde tercih edilir.
# - Örn: MongoDB, Redis, Cassandra
#
# ---
# > Özetlemek Gerekirse:
#
# Yapılandırılmış verilerde İlişkisel Veritabanları (Relational Databases) tercih edilirken, bankacılık sistemlerinde yer alan transaction işlemleri düşünülebilir.
#
# Yapısal Olmayan Verilerde => NoSQL (Not Only SQL) kullanılabilir. Bir X platformunda yayınlamış olduğunuz tweeti düşünebilirsiniz.

# %% [markdown]
# ### Veri tabanı oluşturmak:
# ```sql
# CREATE DATABASE VeriTabaniIsmi
# ```
# ### Veri Çekmek
# ```sql
# SELECT * FROM TabloIsmi -- Butun sutunlari ceker
#
# SELECT IlgiliSutunlar FROM TabloIsmi -- ilgili sutunu getirir.
#
# -- Veri Filtrelemek icin WHERE
# SELECT IlgiliSutunlar FROM TabloIsmi WHERE Sart
#
# -- ornek
# SELECT Name WHERE Name = 'emre'
# ```
#
# ### Tablo Oluşturmak
# ```sql
# CREATE TABLE TabloIsmi(sutun_ismi veripi)
# ```
#
# ### Tabloya Veri Eklemek
# ```sql
# INSERT INTO TabloAdi(sutun_adi1, sutun_adi2 ...) VALUES(deger1, deger2, ...)
# ```
#
# ### Tablodan Veri Silmek
# ```sql
# -- Tabloyu silmek
# DROP TABLE TabloIsmi;
#
# DELETE FROM TabloIsmi WHERE SART
# ```
#
# ```sql
# -- MySQL ve PostgreSQL'de IF NOT EXISTS
# CREATE TABLE IF NOT EXISTS Students(
#     ID INTEGER PRIMARY KEY,
#     NAME VARCHAR(30),
#     SURNAME VARCHAR(30),
#     AGE TINYINT)
# ```
#
# ```sql
# -- Veri ekleyelim
# INSERT INTO Students (
#     NAME,
#     SURNAME
#     ) VALUES(
#         'Emre',
#         'Ustubec'
#         )
# ```
